# %% [markdown]
# ### Build an MLP with residual connections for ECG Signal Classification (5 classes)  - Pytorch

# %% [markdown]
# ### Read H4P2_torchview.ipynb first

# %%
#Create your "signature"
#Run this cell but do NOT modify the code.
#The signature needs to be displayed right below the cell in this file.
#You will get zero point if the signature is not displayed.     
import platform, socket, getpass
from time import time
from datetime import datetime
import random
signature=[socket.gethostbyname(socket.gethostname()),
           getpass.getuser(),
           datetime.now(),
           random.random()]
print(signature)
# Out:
# ['10.5.0.2', 'ARamo', datetime.datetime(2025, 11, 24, 19, 36, 59, 167688), 0.04839436550721021]

# %%
#do not modify this cell
import os
import numpy as np
np.random.seed(seed=None)
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim
import platform, socket, getpass
from time import time
from datetime import datetime

# %% [markdown]
# ### Design an MLP -  modify the cell below

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        #-------------------------------------------Instructions------------------------------------------
        # replace each * with a suitable layer according to the diagram in Homework4.pdf
        #   for example: change self.linear1 = * to self.linear1=nn.Linear(in_features=?, out_features=?)
        # replace each ? with a suitable value
        #   for example: change in_features=? to in_features=187 in self.linear1
        # do NOT replace/change anything eslse
        # do NOT add new layers        
        #--------------------------------------------------------------------------------------------------
        self.linear1 = nn.Linear(in_features=187, out_features=256)
        self.linear2 = nn.Linear(in_features=256, out_features=256)
        self.norm3 = nn.LayerNorm(normalized_shape=256)# only replace ? with a suitable value
        self.linear3 = nn.Linear(in_features=256, out_features=256)
        self.norm4 = nn.LayerNorm(normalized_shape=256)# only replace ? with a suitable value
        self.linear4 = nn.Linear(in_features=256, out_features=256)
        self.norm5 = nn.LayerNorm(normalized_shape=256)# only replace ? with a suitable value
        self.linear5 = nn.Linear(in_features=256, out_features=256)
        self.linear6 = nn.Linear(in_features=256, out_features=5)
                
    def forward(self, x):
        #-----------------Instructions---------------------------------
        #connect the layers according to the diagram in Homework4.pdf
        #ReLU in the diagram refers to nnF.relu, which is used here
        #use variable names according to the diagram in Homework4.pdf
        #    for example  x1=nnF.relu(self.linear(x))        
        #to debug you code: print the shape of the output from every layer
        #    for example: print("x1", x1.shape)
        #--------------------------------------------------------------
        x1 = nnF.relu(self.linear1(x))
        
        x2 = self.linear2(x1)
        x2 = self.norm3(nnF.relu(x2 + x1))
        
        x3 = self.linear3(x2)
        x3 = self.norm4(nnF.relu(x3 + x2))
        
        x4 = self.linear4(x3)
        x4 = self.norm5(nnF.relu(x4 + x3))
        
        x5 = nnF.relu(self.linear5(x4))
        
        z = self.linear6(x5)
        
        return z

# %%
#debug your network here
model=Net()
x=torch.rand(10,187)
z=model(x)
print(z.shape) # (10, 5)
# Out:
# torch.Size([10, 5])

# %% [markdown]
# ### Read and Run, but do NOT modify any code below this line
# ### You may get zero score if you modify any code below this line

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        optimizer.zero_grad()#clear grad of each parameter
        loss.backward()#backward pass
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1, norm_type=2)
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5), dtype=np.int64)
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result,
                'other':[platform.node(), 
                         socket.gethostbyname(socket.gethostname()), 
                         getpass.getuser(),
                         datetime.now(),
                         np.random.rand()]},
               filename)
    print('saved:', filename)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
#use a smaller batch_size if necessary
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
x=dataset_train[0][0]
x=x.view(1,187).to(device)
z=model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1975, 0.1421, 0.1831, 0.2720, 0.2053]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# choose an optimization method

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001, amsgrad=True)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
val_acc_best=0

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(0, 100): 
    t0=time()
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    if acc_val > val_acc_best:
        val_acc_best=acc_val
        result = (loss_train_list, acc_train_list, 
                  acc_val_list, other_val)
        save_checkpoint('H4P2T1_MLP_best.pt', model, optimizer, result, epoch)    
    t1=time()
    print('epoch', epoch, 'time cost:', t1-t0)
# Out:
# Train Epoch: 0 [0%]	Loss: 1.698283
# epoch 0 training loss: 0.9795118136839434 acc: 0.6204775687409552
# epoch 0 validation acc: 0.7305195
# saved: H4P2T1_MLP_best.pt
# epoch 0 time cost: 0.16531920433044434
# Train Epoch: 1 [0%]	Loss: 0.536716
# epoch 1 training loss: 0.6160300021821802 acc: 0.7688133140376266
# epoch 1 validation acc: 0.762987
# saved: H4P2T1_MLP_best.pt
# epoch 1 time cost: 0.16345596313476562
# Train Epoch: 2 [0%]	Loss: 0.602290
# epoch 2 training loss: 0.48291484063321893 acc: 0.8115050651230101
# epoch 2 validation acc: 0.79545456
# saved: H4P2T1_MLP_best.pt
# epoch 2 time cost: 0.1769254207611084
# Train Epoch: 3 [0%]	Loss: 0.444479
# epoch 1 training loss: 0.6160300021821802 acc: 0.7688133140376266
# epoch 1 validation acc: 0.762987
# saved: H4P2T1_MLP_best.pt
# epoch 1 time cost: 0.16345596313476562
# Train Epoch: 2 [0%]	Loss: 0.602290
# epoch 2 training loss: 0.48291484063321893 acc: 0.8115050651230101
# epoch 2 validation acc: 0.79545456
# saved: H4P2T1_MLP_best.pt
# epoch 2 time cost: 0.1769254207611084
# Train Epoch: 3 [0%]	Loss: 0.444479
# epoch 3 training loss: 0.4228451577099887 acc: 0.8469609261939218
# epoch 3 validation acc: 0.8084416
# saved: H4P2T1_MLP_best.pt
# epoch 3 time cost: 0.18678855895996094
# Train Epoch: 4 [0%]	Loss: 0.336833
# epoch 4 training loss: 0.3669194016944278 acc: 0.869753979739508
# epoch 4 validation acc: 0.83116883
# saved: H4P2T1_MLP_best.pt
# epoch 4 time cost: 0.15764760971069336
# Train Epoch: 5 [0%]	Loss: 0.244673
# epoch 3 training loss: 0.4228451577099887 acc: 0.8469609261939218
# epoch 3 validation acc: 0.8084416
# saved: H4P2T1_MLP_best.pt
# epoch 3 time cost: 0.18678855895996094
# Train Epoch: 4 [0%]	Loss: 0.336833
# epoch 4 training loss: 0.3669194016944278 acc: 0.869753979739508
# epoch 4 validation acc: 0.83116883
# saved: H4P2T1_MLP_best.pt
# epoch 4 time cost: 0.15764760971069336
# Train Epoch: 5 [0%]	Loss: 0.244673
# epoch 5 training loss: 0.31853018497878854 acc: 0.8871201157742402
# epoch 5 validation acc: 0.8214286
# epoch 5 time cost: 0.15581893920898438
# Train Epoch: 6 [0%]	Loss: 0.352786
# epoch 6 training loss: 0.2986543225971135 acc: 0.8976121562952243
# epoch 6 validation acc: 0.85064936
# saved: H4P2T1_MLP_best.pt
# epoch 6 time cost: 0.15570807456970215
# Train Epoch: 7 [0%]	Loss: 0.249547
# epoch 5 training loss: 0.31853018497878854 acc: 0.8871201157742402
# epoch 5 validation acc: 0.8214286
# epoch 5 time cost: 0.15581893920898438
# Train Epoch: 6 [0%]	Loss: 0.352786
# epoch 6 training loss: 0.2986543225971135 acc: 0.8976121562952243
# epoch 6 validation acc: 0.85064936
# saved: H4P2T1_MLP_best.pt
# epoch 6 time cost: 0.15570807456970215
# Train Epoch: 7 [0%]	Loss: 0.249547
# epoch 7 training loss: 0.26356018673289905 acc: 0.8979739507959479
# epoch 7 validation acc: 0.85064936
# epoch 7 time cost: 0.168961763381958
# Train Epoch: 8 [0%]	Loss: 0.155343
# epoch 8 training loss: 0.2209766564721411 acc: 0.920767004341534
# epoch 8 validation acc: 0.8538961
# saved: H4P2T1_MLP_best.pt
# epoch 8 time cost: 0.15306806564331055
# Train Epoch: 9 [0%]	Loss: 0.164462
# epoch 7 training loss: 0.26356018673289905 acc: 0.8979739507959479
# epoch 7 validation acc: 0.85064936
# epoch 7 time cost: 0.168961763381958
# Train Epoch: 8 [0%]	Loss: 0.155343
# epoch 8 training loss: 0.2209766564721411 acc: 0.920767004341534
# epoch 8 validation acc: 0.8538961
# saved: H4P2T1_MLP_best.pt
# epoch 8 time cost: 0.15306806564331055
# Train Epoch: 9 [0%]	Loss: 0.164462
# epoch 9 training loss: 0.19095064157789404 acc: 0.9316208393632417
# epoch 9 validation acc: 0.8538961
# epoch 9 time cost: 0.15256428718566895
# Train Epoch: 10 [0%]	Loss: 0.146465
# epoch 10 training loss: 0.16523294421759518 acc: 0.9406657018813314
# epoch 10 validation acc: 0.83116883
# epoch 10 time cost: 0.1470201015472412
# Train Epoch: 11 [0%]	Loss: 0.111346
# epoch 9 training loss: 0.19095064157789404 acc: 0.9316208393632417
# epoch 9 validation acc: 0.8538961
# epoch 9 time cost: 0.15256428718566895
# Train Epoch: 10 [0%]	Loss: 0.146465
# epoch 10 training loss: 0.16523294421759518 acc: 0.9406657018813314
# epoch 10 validation acc: 0.83116883
# epoch 10 time cost: 0.1470201015472412
# Train Epoch: 11 [0%]	Loss: 0.111346
# epoch 11 training loss: 0.1653260842643001 acc: 0.9359623733719248
# epoch 11 validation acc: 0.8149351
# epoch 11 time cost: 0.14700841903686523
# Train Epoch: 12 [0%]	Loss: 0.108395
# epoch 12 training loss: 0.1400286734781482 acc: 0.9464544138929089
# epoch 12 validation acc: 0.8636364
# saved: H4P2T1_MLP_best.pt
# epoch 12 time cost: 0.1535205841064453
# Train Epoch: 13 [0%]	Loss: 0.086759
# epoch 11 training loss: 0.1653260842643001 acc: 0.9359623733719248
# epoch 11 validation acc: 0.8149351
# epoch 11 time cost: 0.14700841903686523
# Train Epoch: 12 [0%]	Loss: 0.108395
# epoch 12 training loss: 0.1400286734781482 acc: 0.9464544138929089
# epoch 12 validation acc: 0.8636364
# saved: H4P2T1_MLP_best.pt
# epoch 12 time cost: 0.1535205841064453
# Train Epoch: 13 [0%]	Loss: 0.086759
# epoch 13 training loss: 0.12976150587201118 acc: 0.953328509406657
# epoch 13 validation acc: 0.85064936
# epoch 13 time cost: 0.1611185073852539
# Train Epoch: 14 [0%]	Loss: 0.115629
# epoch 14 training loss: 0.11666821993210098 acc: 0.9562228654124457
# epoch 14 validation acc: 0.85714287
# epoch 14 time cost: 0.1409773826599121
# Train Epoch: 15 [0%]	Loss: 0.074433
# epoch 13 training loss: 0.12976150587201118 acc: 0.953328509406657
# epoch 13 validation acc: 0.85064936
# epoch 13 time cost: 0.1611185073852539
# Train Epoch: 14 [0%]	Loss: 0.115629
# epoch 14 training loss: 0.11666821993210098 acc: 0.9562228654124457
# epoch 14 validation acc: 0.85714287
# epoch 14 time cost: 0.1409773826599121
# Train Epoch: 15 [0%]	Loss: 0.074433
# epoch 15 training loss: 0.10779710503464396 acc: 0.9583936324167872
# epoch 15 validation acc: 0.84090906
# epoch 15 time cost: 0.1349656581878662
# Train Epoch: 16 [0%]	Loss: 0.082004
# epoch 16 training loss: 0.10210284031927586 acc: 0.9620115774240231
# epoch 16 validation acc: 0.8701299
# saved: H4P2T1_MLP_best.pt
# epoch 16 time cost: 0.15814995765686035
# Train Epoch: 17 [0%]	Loss: 0.077162
# epoch 15 training loss: 0.10779710503464396 acc: 0.9583936324167872
# epoch 15 validation acc: 0.84090906
# epoch 15 time cost: 0.1349656581878662
# Train Epoch: 16 [0%]	Loss: 0.082004
# epoch 16 training loss: 0.10210284031927586 acc: 0.9620115774240231
# epoch 16 validation acc: 0.8701299
# saved: H4P2T1_MLP_best.pt
# epoch 16 time cost: 0.15814995765686035
# Train Epoch: 17 [0%]	Loss: 0.077162
# epoch 17 training loss: 0.09644216315990145 acc: 0.9667149059334298
# epoch 17 validation acc: 0.85064936
# epoch 17 time cost: 0.1464369297027588
# Train Epoch: 18 [0%]	Loss: 0.099810
# epoch 18 training loss: 0.11299255388704213 acc: 0.9511577424023154
# epoch 18 validation acc: 0.85714287
# epoch 18 time cost: 0.14980649948120117
# Train Epoch: 19 [0%]	Loss: 0.085250
# epoch 17 training loss: 0.09644216315990145 acc: 0.9667149059334298
# epoch 17 validation acc: 0.85064936
# epoch 17 time cost: 0.1464369297027588
# Train Epoch: 18 [0%]	Loss: 0.099810
# epoch 18 training loss: 0.11299255388704213 acc: 0.9511577424023154
# epoch 18 validation acc: 0.85714287
# epoch 18 time cost: 0.14980649948120117
# Train Epoch: 19 [0%]	Loss: 0.085250
# epoch 19 training loss: 0.09336464919827202 acc: 0.9692474674384949
# epoch 19 validation acc: 0.8474026
# epoch 19 time cost: 0.14630722999572754
# Train Epoch: 20 [0%]	Loss: 0.142564
# epoch 20 training loss: 0.0797877511517568 acc: 0.9743125904486252
# epoch 20 validation acc: 0.8538961
# epoch 20 time cost: 0.1435086727142334
# Train Epoch: 21 [0%]	Loss: 0.043292
# epoch 19 training loss: 0.09336464919827202 acc: 0.9692474674384949
# epoch 19 validation acc: 0.8474026
# epoch 19 time cost: 0.14630722999572754
# Train Epoch: 20 [0%]	Loss: 0.142564
# epoch 20 training loss: 0.0797877511517568 acc: 0.9743125904486252
# epoch 20 validation acc: 0.8538961
# epoch 20 time cost: 0.1435086727142334
# Train Epoch: 21 [0%]	Loss: 0.043292
# epoch 21 training loss: 0.14292593452740798 acc: 0.953328509406657
# epoch 21 validation acc: 0.8474026
# epoch 21 time cost: 0.13120031356811523
# Train Epoch: 22 [0%]	Loss: 0.127855
# epoch 22 training loss: 0.07317779060791839 acc: 0.9739507959479016
# epoch 22 validation acc: 0.8474026
# epoch 22 time cost: 0.1475691795349121
# Train Epoch: 23 [0%]	Loss: 0.043977
# epoch 21 training loss: 0.14292593452740798 acc: 0.953328509406657
# epoch 21 validation acc: 0.8474026
# epoch 21 time cost: 0.13120031356811523
# Train Epoch: 22 [0%]	Loss: 0.127855
# epoch 22 training loss: 0.07317779060791839 acc: 0.9739507959479016
# epoch 22 validation acc: 0.8474026
# epoch 22 time cost: 0.1475691795349121
# Train Epoch: 23 [0%]	Loss: 0.043977
# epoch 23 training loss: 0.08727371870455417 acc: 0.9670767004341534
# epoch 23 validation acc: 0.83441556
# epoch 23 time cost: 0.13979434967041016
# Train Epoch: 24 [0%]	Loss: 0.091552
# epoch 24 training loss: 0.09371783042495901 acc: 0.9652677279305355
# epoch 24 validation acc: 0.8701299
# epoch 24 time cost: 0.15612363815307617
# Train Epoch: 25 [0%]	Loss: 0.068203
# epoch 23 training loss: 0.08727371870455417 acc: 0.9670767004341534
# epoch 23 validation acc: 0.83441556
# epoch 23 time cost: 0.13979434967041016
# Train Epoch: 24 [0%]	Loss: 0.091552
# epoch 24 training loss: 0.09371783042495901 acc: 0.9652677279305355
# epoch 24 validation acc: 0.8701299
# epoch 24 time cost: 0.15612363815307617
# Train Epoch: 25 [0%]	Loss: 0.068203
# epoch 25 training loss: 0.09344923767176541 acc: 0.9667149059334298
# epoch 25 validation acc: 0.8246753
# epoch 25 time cost: 0.14203524589538574
# Train Epoch: 26 [0%]	Loss: 0.058576
# epoch 26 training loss: 0.08215486766262488 acc: 0.9703328509406657
# epoch 26 validation acc: 0.8474026
# epoch 26 time cost: 0.1658461093902588
# Train Epoch: 27 [0%]	Loss: 0.120080
# epoch 25 training loss: 0.09344923767176541 acc: 0.9667149059334298
# epoch 25 validation acc: 0.8246753
# epoch 25 time cost: 0.14203524589538574
# Train Epoch: 26 [0%]	Loss: 0.058576
# epoch 26 training loss: 0.08215486766262488 acc: 0.9703328509406657
# epoch 26 validation acc: 0.8474026
# epoch 26 time cost: 0.1658461093902588
# Train Epoch: 27 [0%]	Loss: 0.120080
# epoch 27 training loss: 0.09079008744182912 acc: 0.9645441389290883
# epoch 27 validation acc: 0.8668831
# epoch 27 time cost: 0.1530613899230957
# Train Epoch: 28 [0%]	Loss: 0.067802
# epoch 28 training loss: 0.06311939161440189 acc: 0.9790159189580319
# epoch 28 validation acc: 0.8701299
# epoch 28 time cost: 0.13060784339904785
# Train Epoch: 29 [0%]	Loss: 0.033381
# epoch 27 training loss: 0.09079008744182912 acc: 0.9645441389290883
# epoch 27 validation acc: 0.8668831
# epoch 27 time cost: 0.1530613899230957
# Train Epoch: 28 [0%]	Loss: 0.067802
# epoch 28 training loss: 0.06311939161440189 acc: 0.9790159189580319
# epoch 28 validation acc: 0.8701299
# epoch 28 time cost: 0.13060784339904785
# Train Epoch: 29 [0%]	Loss: 0.033381
# epoch 29 training loss: 0.06477242344143716 acc: 0.9786541244573083
# epoch 29 validation acc: 0.85714287
# epoch 29 time cost: 0.13836979866027832
# Train Epoch: 30 [0%]	Loss: 0.057923
# epoch 30 training loss: 0.07031206185506149 acc: 0.9790159189580319
# epoch 30 validation acc: 0.85714287
# epoch 30 time cost: 0.12655949592590332
# Train Epoch: 31 [0%]	Loss: 0.095167
# epoch 29 training loss: 0.06477242344143716 acc: 0.9786541244573083
# epoch 29 validation acc: 0.85714287
# epoch 29 time cost: 0.13836979866027832
# Train Epoch: 30 [0%]	Loss: 0.057923
# epoch 30 training loss: 0.07031206185506149 acc: 0.9790159189580319
# epoch 30 validation acc: 0.85714287
# epoch 30 time cost: 0.12655949592590332
# Train Epoch: 31 [0%]	Loss: 0.095167
# epoch 31 training loss: 0.057324237105521286 acc: 0.9797395079594791
# epoch 31 validation acc: 0.83766234
# epoch 31 time cost: 0.13218045234680176
# Train Epoch: 32 [0%]	Loss: 0.042850
# epoch 32 training loss: 0.07991885220293295 acc: 0.9743125904486252
# epoch 32 validation acc: 0.84415585
# epoch 32 time cost: 0.12987351417541504
# Train Epoch: 33 [0%]	Loss: 0.093521
# epoch 31 training loss: 0.057324237105521286 acc: 0.9797395079594791
# epoch 31 validation acc: 0.83766234
# epoch 31 time cost: 0.13218045234680176
# Train Epoch: 32 [0%]	Loss: 0.042850
# epoch 32 training loss: 0.07991885220293295 acc: 0.9743125904486252
# epoch 32 validation acc: 0.84415585
# epoch 32 time cost: 0.12987351417541504
# Train Epoch: 33 [0%]	Loss: 0.093521
# epoch 33 training loss: 0.06385262666100805 acc: 0.9772069464544139
# epoch 33 validation acc: 0.8636364
# epoch 33 time cost: 0.13934683799743652
# Train Epoch: 34 [0%]	Loss: 0.051010
# epoch 34 training loss: 0.07179050401530483 acc: 0.973589001447178
# epoch 34 validation acc: 0.8636364
# epoch 34 time cost: 0.13136005401611328
# Train Epoch: 35 [0%]	Loss: 0.020447
# epoch 33 training loss: 0.06385262666100805 acc: 0.9772069464544139
# epoch 33 validation acc: 0.8636364
# epoch 33 time cost: 0.13934683799743652
# Train Epoch: 34 [0%]	Loss: 0.051010
# epoch 34 training loss: 0.07179050401530483 acc: 0.973589001447178
# epoch 34 validation acc: 0.8636364
# epoch 34 time cost: 0.13136005401611328
# Train Epoch: 35 [0%]	Loss: 0.020447
# epoch 35 training loss: 0.06250248832458799 acc: 0.9739507959479016
# epoch 35 validation acc: 0.8603896
# epoch 35 time cost: 0.1323084831237793
# Train Epoch: 36 [0%]	Loss: 0.025319
# epoch 36 training loss: 0.07231830373745073 acc: 0.9743125904486252
# epoch 36 validation acc: 0.84415585
# epoch 36 time cost: 0.13230586051940918
# Train Epoch: 37 [0%]	Loss: 0.087748
# epoch 35 training loss: 0.06250248832458799 acc: 0.9739507959479016
# epoch 35 validation acc: 0.8603896
# epoch 35 time cost: 0.1323084831237793
# Train Epoch: 36 [0%]	Loss: 0.025319
# epoch 36 training loss: 0.07231830373745073 acc: 0.9743125904486252
# epoch 36 validation acc: 0.84415585
# epoch 36 time cost: 0.13230586051940918
# Train Epoch: 37 [0%]	Loss: 0.087748
# epoch 37 training loss: 0.06717559758743102 acc: 0.9804630969609262
# epoch 37 validation acc: 0.8636364
# epoch 37 time cost: 0.1362781524658203
# Train Epoch: 38 [0%]	Loss: 0.068727
# epoch 38 training loss: 0.07585957891900431 acc: 0.9743125904486252
# epoch 38 validation acc: 0.85714287
# epoch 38 time cost: 0.13472867012023926
# Train Epoch: 39 [0%]	Loss: 0.039100
# epoch 37 training loss: 0.06717559758743102 acc: 0.9804630969609262
# epoch 37 validation acc: 0.8636364
# epoch 37 time cost: 0.1362781524658203
# Train Epoch: 38 [0%]	Loss: 0.068727
# epoch 38 training loss: 0.07585957891900431 acc: 0.9743125904486252
# epoch 38 validation acc: 0.85714287
# epoch 38 time cost: 0.13472867012023926
# Train Epoch: 39 [0%]	Loss: 0.039100
# epoch 39 training loss: 0.07489779498428106 acc: 0.9750361794500724
# epoch 39 validation acc: 0.8474026
# epoch 39 time cost: 0.12813401222229004
# Train Epoch: 40 [0%]	Loss: 0.021513
# epoch 40 training loss: 0.06504072223535994 acc: 0.9746743849493488
# epoch 40 validation acc: 0.8636364
# epoch 40 time cost: 0.13351106643676758
# Train Epoch: 41 [0%]	Loss: 0.069857
# epoch 39 training loss: 0.07489779498428106 acc: 0.9750361794500724
# epoch 39 validation acc: 0.8474026
# epoch 39 time cost: 0.12813401222229004
# Train Epoch: 40 [0%]	Loss: 0.021513
# epoch 40 training loss: 0.06504072223535994 acc: 0.9746743849493488
# epoch 40 validation acc: 0.8636364
# epoch 40 time cost: 0.13351106643676758
# Train Epoch: 41 [0%]	Loss: 0.069857
# epoch 41 training loss: 0.06359106412326748 acc: 0.9757597684515196
# epoch 41 validation acc: 0.8603896
# epoch 41 time cost: 0.13751697540283203
# Train Epoch: 42 [0%]	Loss: 0.024943
# epoch 42 training loss: 0.048677562016316435 acc: 0.9822720694645442
# epoch 42 validation acc: 0.84415585
# epoch 42 time cost: 0.12425422668457031
# Train Epoch: 43 [0%]	Loss: 0.054877
# epoch 41 training loss: 0.06359106412326748 acc: 0.9757597684515196
# epoch 41 validation acc: 0.8603896
# epoch 41 time cost: 0.13751697540283203
# Train Epoch: 42 [0%]	Loss: 0.024943
# epoch 42 training loss: 0.048677562016316435 acc: 0.9822720694645442
# epoch 42 validation acc: 0.84415585
# epoch 42 time cost: 0.12425422668457031
# Train Epoch: 43 [0%]	Loss: 0.054877
# epoch 43 training loss: 0.05967380123382265 acc: 0.9779305354558611
# epoch 43 validation acc: 0.84415585
# epoch 43 time cost: 0.13665151596069336
# Train Epoch: 44 [0%]	Loss: 0.012414
# epoch 44 training loss: 0.06811724594709548 acc: 0.9793777134587555
# epoch 44 validation acc: 0.8603896
# epoch 44 time cost: 0.12420940399169922
# Train Epoch: 45 [0%]	Loss: 0.024772
# epoch 43 training loss: 0.05967380123382265 acc: 0.9779305354558611
# epoch 43 validation acc: 0.84415585
# epoch 43 time cost: 0.13665151596069336
# Train Epoch: 44 [0%]	Loss: 0.012414
# epoch 44 training loss: 0.06811724594709548 acc: 0.9793777134587555
# epoch 44 validation acc: 0.8603896
# epoch 44 time cost: 0.12420940399169922
# Train Epoch: 45 [0%]	Loss: 0.024772
# epoch 45 training loss: 0.05619210318069567 acc: 0.9804630969609262
# epoch 45 validation acc: 0.84090906
# epoch 45 time cost: 0.12897944450378418
# Train Epoch: 46 [0%]	Loss: 0.058306
# epoch 46 training loss: 0.04761009561744603 acc: 0.983357452966715
# epoch 46 validation acc: 0.8733766
# saved: H4P2T1_MLP_best.pt
# epoch 46 time cost: 0.13539981842041016
# Train Epoch: 47 [0%]	Loss: 0.045846
# epoch 45 training loss: 0.05619210318069567 acc: 0.9804630969609262
# epoch 45 validation acc: 0.84090906
# epoch 45 time cost: 0.12897944450378418
# Train Epoch: 46 [0%]	Loss: 0.058306
# epoch 46 training loss: 0.04761009561744603 acc: 0.983357452966715
# epoch 46 validation acc: 0.8733766
# saved: H4P2T1_MLP_best.pt
# epoch 46 time cost: 0.13539981842041016
# Train Epoch: 47 [0%]	Loss: 0.045846
# epoch 47 training loss: 0.05272007416087118 acc: 0.9797395079594791
# epoch 47 validation acc: 0.8766234
# saved: H4P2T1_MLP_best.pt
# epoch 47 time cost: 0.14326047897338867
# Train Epoch: 48 [0%]	Loss: 0.023049
# epoch 48 training loss: 0.04841721650551666 acc: 0.9808248914616498
# epoch 48 validation acc: 0.8636364
# epoch 48 time cost: 0.12705779075622559
# Train Epoch: 49 [0%]	Loss: 0.083410
# epoch 47 training loss: 0.05272007416087118 acc: 0.9797395079594791
# epoch 47 validation acc: 0.8766234
# saved: H4P2T1_MLP_best.pt
# epoch 47 time cost: 0.14326047897338867
# Train Epoch: 48 [0%]	Loss: 0.023049
# epoch 48 training loss: 0.04841721650551666 acc: 0.9808248914616498
# epoch 48 validation acc: 0.8636364
# epoch 48 time cost: 0.12705779075622559
# Train Epoch: 49 [0%]	Loss: 0.083410
# epoch 49 training loss: 0.05011136243543164 acc: 0.9829956584659914
# epoch 49 validation acc: 0.8798701
# saved: H4P2T1_MLP_best.pt
# epoch 49 time cost: 0.14716172218322754
# Train Epoch: 50 [0%]	Loss: 0.011368
# epoch 50 training loss: 0.03671247960830277 acc: 0.9876989869753979
# epoch 50 validation acc: 0.8538961
# epoch 50 time cost: 0.1412663459777832
# Train Epoch: 51 [0%]	Loss: 0.014437
# epoch 49 training loss: 0.05011136243543164 acc: 0.9829956584659914
# epoch 49 validation acc: 0.8798701
# saved: H4P2T1_MLP_best.pt
# epoch 49 time cost: 0.14716172218322754
# Train Epoch: 50 [0%]	Loss: 0.011368
# epoch 50 training loss: 0.03671247960830277 acc: 0.9876989869753979
# epoch 50 validation acc: 0.8538961
# epoch 50 time cost: 0.1412663459777832
# Train Epoch: 51 [0%]	Loss: 0.014437
# epoch 51 training loss: 0.039386536947197535 acc: 0.9851664254703328
# epoch 51 validation acc: 0.8603896
# epoch 51 time cost: 0.12625598907470703
# Train Epoch: 52 [0%]	Loss: 0.103531
# epoch 52 training loss: 0.05900697418573228 acc: 0.9775687409551375
# epoch 52 validation acc: 0.8636364
# epoch 52 time cost: 0.13217425346374512
# Train Epoch: 53 [0%]	Loss: 0.019872
# epoch 51 training loss: 0.039386536947197535 acc: 0.9851664254703328
# epoch 51 validation acc: 0.8603896
# epoch 51 time cost: 0.12625598907470703
# Train Epoch: 52 [0%]	Loss: 0.103531
# epoch 52 training loss: 0.05900697418573228 acc: 0.9775687409551375
# epoch 52 validation acc: 0.8636364
# epoch 52 time cost: 0.13217425346374512
# Train Epoch: 53 [0%]	Loss: 0.019872
# epoch 53 training loss: 0.05706184920431538 acc: 0.9808248914616498
# epoch 53 validation acc: 0.8668831
# epoch 53 time cost: 0.13147449493408203
# Train Epoch: 54 [0%]	Loss: 0.045868
# epoch 54 training loss: 0.04155651251362129 acc: 0.9829956584659914
# epoch 54 validation acc: 0.8701299
# epoch 54 time cost: 0.13257431983947754
# Train Epoch: 55 [0%]	Loss: 0.083865
# epoch 53 training loss: 0.05706184920431538 acc: 0.9808248914616498
# epoch 53 validation acc: 0.8668831
# epoch 53 time cost: 0.13147449493408203
# Train Epoch: 54 [0%]	Loss: 0.045868
# epoch 54 training loss: 0.04155651251362129 acc: 0.9829956584659914
# epoch 54 validation acc: 0.8701299
# epoch 54 time cost: 0.13257431983947754
# Train Epoch: 55 [0%]	Loss: 0.083865
# epoch 55 training loss: 0.03823967299170115 acc: 0.9876989869753979
# epoch 55 validation acc: 0.84090906
# epoch 55 time cost: 0.12796592712402344
# Train Epoch: 56 [0%]	Loss: 0.017025
# epoch 56 training loss: 0.048966080945154485 acc: 0.9848046309696092
# epoch 56 validation acc: 0.8279221
# epoch 56 time cost: 0.1295032501220703
# Train Epoch: 57 [0%]	Loss: 0.059190
# epoch 55 training loss: 0.03823967299170115 acc: 0.9876989869753979
# epoch 55 validation acc: 0.84090906
# epoch 55 time cost: 0.12796592712402344
# Train Epoch: 56 [0%]	Loss: 0.017025
# epoch 56 training loss: 0.048966080945154485 acc: 0.9848046309696092
# epoch 56 validation acc: 0.8279221
# epoch 56 time cost: 0.1295032501220703
# Train Epoch: 57 [0%]	Loss: 0.059190
# epoch 57 training loss: 0.04710752538151362 acc: 0.984081041968162
# epoch 57 validation acc: 0.85064936
# epoch 57 time cost: 0.13024330139160156
# Train Epoch: 58 [0%]	Loss: 0.004615
# epoch 58 training loss: 0.05105465540493077 acc: 0.9801013024602026
# epoch 58 validation acc: 0.8668831
# epoch 58 time cost: 0.12162041664123535
# Train Epoch: 59 [0%]	Loss: 0.054518
# epoch 57 training loss: 0.04710752538151362 acc: 0.984081041968162
# epoch 57 validation acc: 0.85064936
# epoch 57 time cost: 0.13024330139160156
# Train Epoch: 58 [0%]	Loss: 0.004615
# epoch 58 training loss: 0.05105465540493077 acc: 0.9801013024602026
# epoch 58 validation acc: 0.8668831
# epoch 58 time cost: 0.12162041664123535
# Train Epoch: 59 [0%]	Loss: 0.054518
# epoch 59 training loss: 0.03833871522114019 acc: 0.9887843704775687
# epoch 59 validation acc: 0.8603896
# epoch 59 time cost: 0.1330406665802002
# Train Epoch: 60 [0%]	Loss: 0.011631
# epoch 60 training loss: 0.04002174744594165 acc: 0.9869753979739508
# epoch 60 validation acc: 0.83766234
# epoch 60 time cost: 0.12712836265563965
# Train Epoch: 61 [0%]	Loss: 0.036995
# epoch 59 training loss: 0.03833871522114019 acc: 0.9887843704775687
# epoch 59 validation acc: 0.8603896
# epoch 59 time cost: 0.1330406665802002
# Train Epoch: 60 [0%]	Loss: 0.011631
# epoch 60 training loss: 0.04002174744594165 acc: 0.9869753979739508
# epoch 60 validation acc: 0.83766234
# epoch 60 time cost: 0.12712836265563965
# Train Epoch: 61 [0%]	Loss: 0.036995
# epoch 61 training loss: 0.041329555033536795 acc: 0.9855282199710564
# epoch 61 validation acc: 0.8636364
# epoch 61 time cost: 0.12758493423461914
# Train Epoch: 62 [0%]	Loss: 0.024259
# epoch 62 training loss: 0.03331558752423999 acc: 0.9895079594790159
# epoch 62 validation acc: 0.85064936
# epoch 62 time cost: 0.12477278709411621
# Train Epoch: 63 [0%]	Loss: 0.048160
# epoch 61 training loss: 0.041329555033536795 acc: 0.9855282199710564
# epoch 61 validation acc: 0.8636364
# epoch 61 time cost: 0.12758493423461914
# Train Epoch: 62 [0%]	Loss: 0.024259
# epoch 62 training loss: 0.03331558752423999 acc: 0.9895079594790159
# epoch 62 validation acc: 0.85064936
# epoch 62 time cost: 0.12477278709411621
# Train Epoch: 63 [0%]	Loss: 0.048160
# epoch 63 training loss: 0.038417917379940096 acc: 0.9862518089725036
# epoch 63 validation acc: 0.8636364
# epoch 63 time cost: 0.13273978233337402
# Train Epoch: 64 [0%]	Loss: 0.026773
# epoch 64 training loss: 0.035593024201013825 acc: 0.9884225759768451
# epoch 64 validation acc: 0.83766234
# epoch 64 time cost: 0.13364934921264648
# Train Epoch: 65 [0%]	Loss: 0.014785
# epoch 63 training loss: 0.038417917379940096 acc: 0.9862518089725036
# epoch 63 validation acc: 0.8636364
# epoch 63 time cost: 0.13273978233337402
# Train Epoch: 64 [0%]	Loss: 0.026773
# epoch 64 training loss: 0.035593024201013825 acc: 0.9884225759768451
# epoch 64 validation acc: 0.83766234
# epoch 64 time cost: 0.13364934921264648
# Train Epoch: 65 [0%]	Loss: 0.014785
# epoch 65 training loss: 0.026316918057008563 acc: 0.9876989869753979
# epoch 65 validation acc: 0.8538961
# epoch 65 time cost: 0.13909220695495605
# Train Epoch: 66 [0%]	Loss: 0.012870
# epoch 66 training loss: 0.029225916411219674 acc: 0.9902315484804631
# epoch 66 validation acc: 0.8766234
# epoch 66 time cost: 0.1537632942199707
# Train Epoch: 67 [0%]	Loss: 0.032877
# epoch 65 training loss: 0.026316918057008563 acc: 0.9876989869753979
# epoch 65 validation acc: 0.8538961
# epoch 65 time cost: 0.13909220695495605
# Train Epoch: 66 [0%]	Loss: 0.012870
# epoch 66 training loss: 0.029225916411219674 acc: 0.9902315484804631
# epoch 66 validation acc: 0.8766234
# epoch 66 time cost: 0.1537632942199707
# Train Epoch: 67 [0%]	Loss: 0.032877
# epoch 67 training loss: 0.034939776587469336 acc: 0.9895079594790159
# epoch 67 validation acc: 0.85714287
# epoch 67 time cost: 0.1381087303161621
# Train Epoch: 68 [0%]	Loss: 0.022193
# epoch 68 training loss: 0.03638613334094936 acc: 0.9876989869753979
# epoch 68 validation acc: 0.85064936
# epoch 68 time cost: 0.13122844696044922
# Train Epoch: 69 [0%]	Loss: 0.008309
# epoch 67 training loss: 0.034939776587469336 acc: 0.9895079594790159
# epoch 67 validation acc: 0.85714287
# epoch 67 time cost: 0.1381087303161621
# Train Epoch: 68 [0%]	Loss: 0.022193
# epoch 68 training loss: 0.03638613334094936 acc: 0.9876989869753979
# epoch 68 validation acc: 0.85064936
# epoch 68 time cost: 0.13122844696044922
# Train Epoch: 69 [0%]	Loss: 0.008309
# epoch 69 training loss: 0.038772435329685155 acc: 0.9866136034732272
# epoch 69 validation acc: 0.8603896
# epoch 69 time cost: 0.13391661643981934
# Train Epoch: 70 [0%]	Loss: 0.050470
# epoch 70 training loss: 0.029426087424243717 acc: 0.9887843704775687
# epoch 70 validation acc: 0.8636364
# epoch 70 time cost: 0.13187074661254883
# Train Epoch: 71 [0%]	Loss: 0.010822
# epoch 69 training loss: 0.038772435329685155 acc: 0.9866136034732272
# epoch 69 validation acc: 0.8603896
# epoch 69 time cost: 0.13391661643981934
# Train Epoch: 70 [0%]	Loss: 0.050470
# epoch 70 training loss: 0.029426087424243717 acc: 0.9887843704775687
# epoch 70 validation acc: 0.8636364
# epoch 70 time cost: 0.13187074661254883
# Train Epoch: 71 [0%]	Loss: 0.010822
# epoch 71 training loss: 0.02681609207171608 acc: 0.9902315484804631
# epoch 71 validation acc: 0.8766234
# epoch 71 time cost: 0.12326884269714355
# Train Epoch: 72 [0%]	Loss: 0.004324
# epoch 72 training loss: 0.021032396936789155 acc: 0.9934876989869754
# epoch 72 validation acc: 0.8538961
# epoch 72 time cost: 0.12967395782470703
# Train Epoch: 73 [0%]	Loss: 0.024012
# epoch 71 training loss: 0.02681609207171608 acc: 0.9902315484804631
# epoch 71 validation acc: 0.8766234
# epoch 71 time cost: 0.12326884269714355
# Train Epoch: 72 [0%]	Loss: 0.004324
# epoch 72 training loss: 0.021032396936789155 acc: 0.9934876989869754
# epoch 72 validation acc: 0.8538961
# epoch 72 time cost: 0.12967395782470703
# Train Epoch: 73 [0%]	Loss: 0.024012
# epoch 73 training loss: 0.031708974740467966 acc: 0.9898697539797395
# epoch 73 validation acc: 0.85064936
# epoch 73 time cost: 0.13074922561645508
# Train Epoch: 74 [0%]	Loss: 0.057192
# epoch 74 training loss: 0.039746435639575466 acc: 0.9887843704775687
# epoch 74 validation acc: 0.85064936
# epoch 74 time cost: 0.1291334629058838
# Train Epoch: 75 [0%]	Loss: 0.041913
# epoch 73 training loss: 0.031708974740467966 acc: 0.9898697539797395
# epoch 73 validation acc: 0.85064936
# epoch 73 time cost: 0.13074922561645508
# Train Epoch: 74 [0%]	Loss: 0.057192
# epoch 74 training loss: 0.039746435639575466 acc: 0.9887843704775687
# epoch 74 validation acc: 0.85064936
# epoch 74 time cost: 0.1291334629058838
# Train Epoch: 75 [0%]	Loss: 0.041913
# epoch 75 training loss: 0.04363425472878258 acc: 0.984081041968162
# epoch 75 validation acc: 0.8474026
# epoch 75 time cost: 0.12111115455627441
# Train Epoch: 76 [0%]	Loss: 0.047735
# epoch 76 training loss: 0.05189724001948806 acc: 0.9826338639652678
# epoch 76 validation acc: 0.83766234
# epoch 76 time cost: 0.12101578712463379
# Train Epoch: 77 [0%]	Loss: 0.053428
# epoch 75 training loss: 0.04363425472878258 acc: 0.984081041968162
# epoch 75 validation acc: 0.8474026
# epoch 75 time cost: 0.12111115455627441
# Train Epoch: 76 [0%]	Loss: 0.047735
# epoch 76 training loss: 0.05189724001948806 acc: 0.9826338639652678
# epoch 76 validation acc: 0.83766234
# epoch 76 time cost: 0.12101578712463379
# Train Epoch: 77 [0%]	Loss: 0.053428
# epoch 77 training loss: 0.03512274448505857 acc: 0.9873371924746743
# epoch 77 validation acc: 0.8538961
# epoch 77 time cost: 0.13727498054504395
# Train Epoch: 78 [0%]	Loss: 0.009064
# epoch 78 training loss: 0.03709364161742004 acc: 0.9873371924746743
# epoch 78 validation acc: 0.84415585
# epoch 78 time cost: 0.1292119026184082
# Train Epoch: 79 [0%]	Loss: 0.012850
# epoch 77 training loss: 0.03512274448505857 acc: 0.9873371924746743
# epoch 77 validation acc: 0.8538961
# epoch 77 time cost: 0.13727498054504395
# Train Epoch: 78 [0%]	Loss: 0.009064
# epoch 78 training loss: 0.03709364161742004 acc: 0.9873371924746743
# epoch 78 validation acc: 0.84415585
# epoch 78 time cost: 0.1292119026184082
# Train Epoch: 79 [0%]	Loss: 0.012850
# epoch 79 training loss: 0.03557960457295518 acc: 0.9887843704775687
# epoch 79 validation acc: 0.85064936
# epoch 79 time cost: 0.1284785270690918
# Train Epoch: 80 [0%]	Loss: 0.031490
# epoch 80 training loss: 0.033530545780773864 acc: 0.9891461649782923
# epoch 80 validation acc: 0.8603896
# epoch 80 time cost: 0.13007164001464844
# Train Epoch: 81 [0%]	Loss: 0.072175
# epoch 79 training loss: 0.03557960457295518 acc: 0.9887843704775687
# epoch 79 validation acc: 0.85064936
# epoch 79 time cost: 0.1284785270690918
# Train Epoch: 80 [0%]	Loss: 0.031490
# epoch 80 training loss: 0.033530545780773864 acc: 0.9891461649782923
# epoch 80 validation acc: 0.8603896
# epoch 80 time cost: 0.13007164001464844
# Train Epoch: 81 [0%]	Loss: 0.072175
# epoch 81 training loss: 0.042502704129385 acc: 0.9869753979739508
# epoch 81 validation acc: 0.8603896
# epoch 81 time cost: 0.13553619384765625
# Train Epoch: 82 [0%]	Loss: 0.084499
# epoch 82 training loss: 0.06332314799709077 acc: 0.981548480463097
# epoch 82 validation acc: 0.8538961
# epoch 82 time cost: 0.1339423656463623
# Train Epoch: 83 [0%]	Loss: 0.040077
# epoch 81 training loss: 0.042502704129385 acc: 0.9869753979739508
# epoch 81 validation acc: 0.8603896
# epoch 81 time cost: 0.13553619384765625
# Train Epoch: 82 [0%]	Loss: 0.084499
# epoch 82 training loss: 0.06332314799709077 acc: 0.981548480463097
# epoch 82 validation acc: 0.8538961
# epoch 82 time cost: 0.1339423656463623
# Train Epoch: 83 [0%]	Loss: 0.040077
# epoch 83 training loss: 0.03527793233198198 acc: 0.9869753979739508
# epoch 83 validation acc: 0.8668831
# epoch 83 time cost: 0.12779545783996582
# Train Epoch: 84 [0%]	Loss: 0.078549
# epoch 84 training loss: 0.03785368373659863 acc: 0.9891461649782923
# epoch 84 validation acc: 0.8668831
# epoch 84 time cost: 0.12756943702697754
# Train Epoch: 85 [0%]	Loss: 0.004343
# epoch 83 training loss: 0.03527793233198198 acc: 0.9869753979739508
# epoch 83 validation acc: 0.8668831
# epoch 83 time cost: 0.12779545783996582
# Train Epoch: 84 [0%]	Loss: 0.078549
# epoch 84 training loss: 0.03785368373659863 acc: 0.9891461649782923
# epoch 84 validation acc: 0.8668831
# epoch 84 time cost: 0.12756943702697754
# Train Epoch: 85 [0%]	Loss: 0.004343
# epoch 85 training loss: 0.02348544766110453 acc: 0.9927641099855282
# epoch 85 validation acc: 0.8636364
# epoch 85 time cost: 0.1347813606262207
# Train Epoch: 86 [0%]	Loss: 0.014974
# epoch 86 training loss: 0.02211480949137529 acc: 0.9934876989869754
# epoch 86 validation acc: 0.85064936
# epoch 86 time cost: 0.12340497970581055
# Train Epoch: 87 [0%]	Loss: 0.060447
# epoch 85 training loss: 0.02348544766110453 acc: 0.9927641099855282
# epoch 85 validation acc: 0.8636364
# epoch 85 time cost: 0.1347813606262207
# Train Epoch: 86 [0%]	Loss: 0.014974
# epoch 86 training loss: 0.02211480949137529 acc: 0.9934876989869754
# epoch 86 validation acc: 0.85064936
# epoch 86 time cost: 0.12340497970581055
# Train Epoch: 87 [0%]	Loss: 0.060447
# epoch 87 training loss: 0.029229178664867173 acc: 0.9891461649782923
# epoch 87 validation acc: 0.8474026
# epoch 87 time cost: 0.12799811363220215
# Train Epoch: 88 [0%]	Loss: 0.002682
# epoch 88 training loss: 0.02867365333209322 acc: 0.9909551374819102
# epoch 88 validation acc: 0.8603896
# epoch 88 time cost: 0.134232759475708
# Train Epoch: 89 [0%]	Loss: 0.005964
# epoch 87 training loss: 0.029229178664867173 acc: 0.9891461649782923
# epoch 87 validation acc: 0.8474026
# epoch 87 time cost: 0.12799811363220215
# Train Epoch: 88 [0%]	Loss: 0.002682
# epoch 88 training loss: 0.02867365333209322 acc: 0.9909551374819102
# epoch 88 validation acc: 0.8603896
# epoch 88 time cost: 0.134232759475708
# Train Epoch: 89 [0%]	Loss: 0.005964
# epoch 89 training loss: 0.03337736350526525 acc: 0.9916787264833574
# epoch 89 validation acc: 0.8474026
# epoch 89 time cost: 0.1381375789642334
# Train Epoch: 90 [0%]	Loss: 0.018040
# epoch 90 training loss: 0.01579603892539374 acc: 0.9924023154848046
# epoch 90 validation acc: 0.8603896
# epoch 90 time cost: 0.13441228866577148
# Train Epoch: 91 [0%]	Loss: 0.015041
# epoch 89 training loss: 0.03337736350526525 acc: 0.9916787264833574
# epoch 89 validation acc: 0.8474026
# epoch 89 time cost: 0.1381375789642334
# Train Epoch: 90 [0%]	Loss: 0.018040
# epoch 90 training loss: 0.01579603892539374 acc: 0.9924023154848046
# epoch 90 validation acc: 0.8603896
# epoch 90 time cost: 0.13441228866577148
# Train Epoch: 91 [0%]	Loss: 0.015041
# epoch 91 training loss: 0.0361355513821102 acc: 0.9869753979739508
# epoch 91 validation acc: 0.8538961
# epoch 91 time cost: 0.12880516052246094
# Train Epoch: 92 [0%]	Loss: 0.040182
# epoch 92 training loss: 0.028136707524853675 acc: 0.9916787264833574
# epoch 92 validation acc: 0.84415585
# epoch 92 time cost: 0.12151265144348145
# Train Epoch: 93 [0%]	Loss: 0.054957
# epoch 91 training loss: 0.0361355513821102 acc: 0.9869753979739508
# epoch 91 validation acc: 0.8538961
# epoch 91 time cost: 0.12880516052246094
# Train Epoch: 92 [0%]	Loss: 0.040182
# epoch 92 training loss: 0.028136707524853675 acc: 0.9916787264833574
# epoch 92 validation acc: 0.84415585
# epoch 92 time cost: 0.12151265144348145
# Train Epoch: 93 [0%]	Loss: 0.054957
# epoch 93 training loss: 0.023306514125909995 acc: 0.9927641099855282
# epoch 93 validation acc: 0.85714287
# epoch 93 time cost: 0.1295480728149414
# Train Epoch: 94 [0%]	Loss: 0.034330
# epoch 94 training loss: 0.030435486104000698 acc: 0.9876989869753979
# epoch 94 validation acc: 0.8636364
# epoch 94 time cost: 0.1267704963684082
# Train Epoch: 95 [0%]	Loss: 0.059741
# epoch 93 training loss: 0.023306514125909995 acc: 0.9927641099855282
# epoch 93 validation acc: 0.85714287
# epoch 93 time cost: 0.1295480728149414
# Train Epoch: 94 [0%]	Loss: 0.034330
# epoch 94 training loss: 0.030435486104000698 acc: 0.9876989869753979
# epoch 94 validation acc: 0.8636364
# epoch 94 time cost: 0.1267704963684082
# Train Epoch: 95 [0%]	Loss: 0.059741
# epoch 95 training loss: 0.017544693398204716 acc: 0.993849493487699
# epoch 95 validation acc: 0.84090906
# epoch 95 time cost: 0.13898897171020508
# Train Epoch: 96 [0%]	Loss: 0.005830
# epoch 96 training loss: 0.03578895317729224 acc: 0.9884225759768451
# epoch 96 validation acc: 0.8636364
# epoch 96 time cost: 0.13526439666748047
# Train Epoch: 97 [0%]	Loss: 0.068179
# epoch 95 training loss: 0.017544693398204716 acc: 0.993849493487699
# epoch 95 validation acc: 0.84090906
# epoch 95 time cost: 0.13898897171020508
# Train Epoch: 96 [0%]	Loss: 0.005830
# epoch 96 training loss: 0.03578895317729224 acc: 0.9884225759768451
# epoch 96 validation acc: 0.8636364
# epoch 96 time cost: 0.13526439666748047
# Train Epoch: 97 [0%]	Loss: 0.068179
# epoch 97 training loss: 0.022919261330653997 acc: 0.9931259044862518
# epoch 97 validation acc: 0.8636364
# epoch 97 time cost: 0.1355113983154297
# Train Epoch: 98 [0%]	Loss: 0.003186
# epoch 98 training loss: 0.01807667281669141 acc: 0.993849493487699
# epoch 98 validation acc: 0.8636364
# epoch 98 time cost: 0.13127827644348145
# Train Epoch: 99 [0%]	Loss: 0.012039
# epoch 97 training loss: 0.022919261330653997 acc: 0.9931259044862518
# epoch 97 validation acc: 0.8636364
# epoch 97 time cost: 0.1355113983154297
# Train Epoch: 98 [0%]	Loss: 0.003186
# epoch 98 training loss: 0.01807667281669141 acc: 0.993849493487699
# epoch 98 validation acc: 0.8636364
# epoch 98 time cost: 0.13127827644348145
# Train Epoch: 99 [0%]	Loss: 0.012039
# epoch 99 training loss: 0.03973494605055417 acc: 0.9891461649782923
# epoch 99 validation acc: 0.84090906
# epoch 99 time cost: 0.12554240226745605
# epoch 99 training loss: 0.03973494605055417 acc: 0.9891461649782923
# epoch 99 validation acc: 0.84090906
# epoch 99 time cost: 0.12554240226745605

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# np.int64(49)

# %%
checkpoint=torch.load('H4P2T1_MLP_best.pt', weights_only=False)
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.893368
# Sensitivity [0.79545456 0.87662339 0.91780823 0.95081967 0.94736844]
# Precision [0.85889572 0.82317072 0.88157892 0.92063493 0.98780489]
# Confusion
#  [[140  23   8   3   2]
#  [ 14 135   4   1   0]
#  [  6   1 134   5   0]
#  [  2   0   4 116   0]
#  [  1   5   2   1 162]]

# %% [markdown]
# ### You will get zero score if the test accuracy < 80%

# %%
if acc < 0.8:
    print("zero point for this task")
else:
    print("good job")
# Out:
# good job

# %% [markdown]
# ### submit this ipynb file and H4P2T1_MLP_best.pt if acc >= 0.8
