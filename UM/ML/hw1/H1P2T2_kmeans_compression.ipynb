# %% [markdown]
# ## Homework 1 Part 2 Task 2
# You will use k-means to perform image compression. <br>
# There is an image for testing your code: beach.bmp <br>

# %%
# %pip install seaborn
# %matplotlib inline
from IPython import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
sn.set(style='whitegrid')
# Out:
# Requirement already satisfied: seaborn in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/alexramos/.conda/envs/pytorch2.5/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step-0: read an image from a bmp file

# %%
from skimage import io, img_as_float
I = io.imread('beach.bmp')
I = img_as_float(I)
fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(I)
ax.set_title('beach', fontsize=16)
ax.axis('off')
# Out:
# (np.float64(-0.5), np.float64(319.5), np.float64(213.5), np.float64(-0.5))

# %% [markdown]
# The image I is a 3D numpy array <br>
# I[i,j,k]: i is row index, j is column index, and k is channel (color) index <br>
# I[0,0] is the pixel at row-0 and col-0, and it has three values r,g,b

# %%
I.shape
# Out:
# (214, 320, 3)

# %%
I[0,0]
# Out:
# array([0.43137255, 0.60392157, 0.78823529])

# %% [markdown]
# ### Step-1: prepare the data matrix X
# each row of X should be a data point - a pixel with three values (R, G, B) <br>
# X should have many rows and 3 columns <br>
# X is converted from `I`, you may try the function `reshape` <br>
# The data type of the matrix `X` should be float32

# %%
#your code
# Reshape image I to a 2D array where each row is a pixel (R,G,B)
X = I.reshape(-1, 3).astype(np.float32)
# Check shape and dtype
print(X.shape, X.dtype)
# Out:
# (68480, 3) float32

# %% [markdown]
# ### Step-2: perform k-means on data matrix X
# try different number of clusters, e.g., k=5

# %%
#your code, k is the number of clusters
from sklearn.cluster import KMeans
k = 5  # you can change this value to try different compressions
kmeans = KMeans(n_clusters=k)
labels = kmeans.fit_predict(X)
centers = kmeans.cluster_centers_

# %%
# centers stores the cluster centers
centers[labels].shape
# Out:
# (68480, 3)

# %% [markdown]
# ### Step-3: compress the image using the cluster centers
# Assume you have obtained some cluster centers, e.g., c1, c2, c3 <br>
# Every data point (i.e. every pixel of the image) is assigned to one of the clusters. <br>
# To compress the image, you can follow the steps below:<br>
# 1. Make a copy of the the data matrix X, call it Y
# 2. Then, modify the data matrix Y, such that every data point is replaced by the corresponding cluster center
# 3. Convert the data matrix Y back to an image Ic <br>
# <br>
# in fact, one line of code is enough, you do not need to create Y at all...  <br>

# %%
#your code
# Replace each pixel with its cluster center
Ic = centers[labels].reshape(I.shape)

# %%
Ic.shape
# Out:
# (214, 320, 3)

# %% [markdown]
# ### Step-4: visualize the compressed the image `Ic`

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(Ic)
ax.set_title('beach - compressed', fontsize=16)
ax.axis('off')
# Out:
# (np.float64(-0.5), np.float64(319.5), np.float64(213.5), np.float64(-0.5))

# %% [markdown]
# ### Step-5: save the compressed image to a bmp file

# %%
# normalize the pixel values in the range of 0 ~ 255
Is=255*(Ic- Ic.min())/(Ic.max()-Ic.min())
# chagne datay type to unit8
Is=Is.astype('uint8')
io.imsave('beach_compressed_k' + str(k) + '.bmp', Is)

# %% [markdown]
# You may find out that the two files, beach.bmp and beach_compressed.bmp, have the same size. <br>
# So, it seems nothing is compressed.  <br>
# Now, zip the two files: beach.bmp and beach_compressed.bmp <br>
# Compare the sizes of the zipped files : beach.zip and beach_compressed.zip <br>
# Then, you will know it.  <br>
